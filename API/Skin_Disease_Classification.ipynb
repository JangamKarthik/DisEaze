jpg
# /kaggle/input/isic-skin-disease-image-dataset-labelled/ISIC_Labelled/Vascular lesion/ISIC_0032270.jpg
# /kaggle/input/isic-skin-disease-image-dataset-labelled/ISIC_Labelled/Vascular lesion/ISIC_0068870.jpg

# %%
train_path = '/kaggle/input/isic-2019/ISIC - 2019/train/'
test_path = '/kaggle/input/isic-2019/ISIC - 2019/test/'



train_batches = ImageDataGenerator(validation_split=0.1) \
                .flow_from_directory(directory=train_path,
                                     classes = ['Basal cell carcinoma', 'Dermatofibroma',
                                                'Actinic keratosis', 'Melanoma','Benign keratosis','Melanocytic nevus','Squamous cell carcinoma','Vascular lesion'],
                                     subset='training',
                                     batch_size=10)

validation_batches = ImageDataGenerator(validation_split=0.1) \
                     .flow_from_directory(directory=train_path,
                                          classes = ['Basal cell carcinoma', 'Dermatofibroma',
                                                'Actinic keratosis', 'Melanoma','Benign keratosis','Melanocytic nevus','Squamous cell carcinoma','Vascular lesion'],
                                          subset='validation',
                                          batch_size=10)

test_batches = ImageDataGenerator() \
                    .flow_from_directory(directory=test_path,
                                        classes = ['Basal cell carcinoma', 'Dermatofibroma',
                                                'Actinic keratosis', 'Melanoma','Benign keratosis','Melanocytic nevus','Squamous cell carcinoma','Vascular lesion'],
                                         batch_size=10,
                                         shuffle=False)
# Out:
# Found 19345 images belonging to 8 classes.
# Found 2146 images belonging to 8 classes.
# Found 1930 images belonging to 8 classes.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import layers
import tensorflow.keras
from tensorflow.keras.utils import to_categorical, model_to_dot, plot_model
import tensorflow as tf
train_datagen = ImageDataGenerator(
    rescale= 1./255,
    zoom_range= (0.73, 0.9),
    horizontal_flip= True,
    rotation_range= 10,
    width_shift_range= 0.10,
    fill_mode= 'constant',
    height_shift_range= 0.10,
    brightness_range= (0.55, 0.9),
)

valid_test_datagen = ImageDataGenerator(
    rescale= 1./255,
)

# %%
IMG_SIZE = 128
n_classes = 8

inp = layers.Input(shape=(IMG_SIZE,IMG_SIZE,3))
x1 = layers.Resizing(IMG_SIZE, IMG_SIZE)(inp)
x2 = layers.Rescaling(1./255)(x1)
x3 = layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu',
                   padding = 'same', input_shape=(IMG_SIZE,IMG_SIZE,3))(x2)
x5 = layers.BatchNormalization(axis=-1)(x3)
x6 = layers.MaxPool2D(pool_size=(2, 2))(x5)
x7 = layers.Conv2D(filters=64, kernel_size=(3, 3),
                   activation='relu', padding = 'same')(x6)
x9 = layers.BatchNormalization(axis=-1)(x7)
x10 = layers.MaxPool2D(pool_size=(2, 2))(x9)

x11 = layers.Conv2D(filters=128, kernel_size=(3, 3),
                    activation='relu', padding = 'same')(x10)
x13 = layers.BatchNormalization(axis=-1)(x11)
x14 = layers.MaxPool2D(pool_size=(2, 2))(x13)
x15 = layers.Conv2D(filters=256, kernel_size=(3, 3),
                      activation='relu', padding = 'same')(x14)
x17 = layers.BatchNormalization(axis=-1)(x15)
x18 = layers.MaxPool2D(pool_size=(2, 2))(x17)
y1 = layers.Flatten()(x18)
y2 = layers.Dense(300, activation='relu')(y1)
y3 = layers.Dense(150, activation='relu')(y2)
y4 = layers.Dropout(0.25)(y3)
y = layers.Dense(n_classes, activation='softmax')(y4)

model = tensorflow.keras.Model(inp,y)

# %%
EPOCHS = 5
BATCH_SIZE = 8
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                  loss='categorical_crossentropy',
                  metrics='accuracy')
model.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  resizing_6 (Resizing)       (None, 128, 128, 3)       0
#
#  rescaling_6 (Rescaling)     (None, 128, 128, 3)       0
#
#  conv2d_29 (Conv2D)          (None, 128, 128, 32)      896
#
#  batch_normalization_8 (Bat  (None, 128, 128, 32)      128
#  chNormalization)
#
#  max_pooling2d_14 (MaxPooli  (None, 64, 64, 32)        0
#  ng2D)
#
#  conv2d_30 (Conv2D)          (None, 64, 64, 64)        18496
#
#  batch_normalization_9 (Bat  (None, 64, 64, 64)        256
#  chNormalization)
#
#  max_pooling2d_15 (MaxPooli  (None, 32, 32, 64)        0
#  ng2D)
#
#  conv2d_31 (Conv2D)          (None, 32, 32, 128)       73856
#
#  batch_normalization_10 (Ba  (None, 32, 32, 128)       512
#  tchNormalization)
#
#  max_pooling2d_16 (MaxPooli  (None, 16, 16, 128)       0
#  ng2D)
#
#  conv2d_32 (Conv2D)          (None, 16, 16, 256)       295168
#
#  batch_normalization_11 (Ba  (None, 16, 16, 256)       1024
#  tchNormalization)
#
#  max_pooling2d_17 (MaxPooli  (None, 8, 8, 256)         0
#  ng2D)
#
#  flatten_5 (Flatten)         (None, 16384)             0
#
#  dense_15 (Dense)            (None, 300)               4915500
#
#  dense_16 (Dense)            (None, 150)               45150
#
#  dropout_5 (Dropout)         (None, 150)               0
#
#  dense_17 (Dense)            (None, 8)                 1208
#
# =================================================================
# Total params: 5352194 (20.42 MB)
# Trainable params: 5351234 (20.41 MB)
# Non-trainable params: 960 (3.75 KB)
# _________________________________________________________________

# %%
history = model.fit(x=train_batches,
                            validation_data=validation_batches,
                            steps_per_epoch=len(train_batches),
                            validation_steps=len(validation_batches),
                            epochs=10,
                            batch_size=BATCH_SIZE,
                            verbose=1)
# Out:
# Epoch 1/10
# 1935/1935 [==============================] - 278s 142ms/step - loss: 1.2754 - accuracy: 0.5614 - val_loss: 1.4024 - val_accuracy: 0.5000
# Epoch 2/10
# 1935/1935 [==============================] - 274s 142ms/step - loss: 1.0968 - accuracy: 0.6102 - val_loss: 1.4953 - val_accuracy: 0.4963
# Epoch 3/10
# 1935/1935 [==============================] - 277s 143ms/step - loss: 1.0247 - accuracy: 0.6344 - val_loss: 1.4271 - val_accuracy: 0.5103
# Epoch 4/10
# 1935/1935 [==============================] - 284s 147ms/step - loss: 0.9694 - accuracy: 0.6539 - val_loss: 1.4860 - val_accuracy: 0.4893
# Epoch 5/10
# 1935/1935 [==============================] - 281s 145ms/step - loss: 0.9064 - accuracy: 0.6739 - val_loss: 1.5400 - val_accuracy: 0.4651
# Epoch 6/10
# 1935/1935 [==============================] - 276s 143ms/step - loss: 0.8504 - accuracy: 0.6900 - val_loss: 1.4356 - val_accuracy: 0.5214
# Epoch 7/10
# 1935/1935 [==============================] - 273s 141ms/step - loss: 0.7802 - accuracy: 0.7140 - val_loss: 1.4388 - val_accuracy: 0.5028
# Epoch 8/10
# 1935/1935 [==============================] - 277s 143ms/step - loss: 0.6950 - accuracy: 0.7475 - val_loss: 1.6248 - val_accuracy: 0.4991
# Epoch 9/10
# 1935/1935 [==============================] - 273s 141ms/step - loss: 0.6046 - accuracy: 0.7808 - val_loss: 1.5524 - val_accuracy: 0.5238
# Epoch 10/10
# 1935/1935 [==============================] - 275s 142ms/step - loss: 0.5040 - accuracy: 0.8149 - val_loss: 2.1254 - val_accuracy: 0.5023

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import seaborn as sn
num_classes = len(train_batches.class_indices)
train_labels = train_batches.classes
train_labels = to_categorical(train_labels, num_classes=num_classes)
valid_labels = validation_batches.classes
valid_labels = to_categorical(valid_labels, num_classes=num_classes)
nb_train_samples = len(train_batches.filenames)
nb_valid_samples = len(validation_batches.filenames)
nb_test_samples = len(test_batches.filenames)
Y_pred = model.predict(test_batches, nb_test_samples // BATCH_SIZE+1)
y_pred = np.argmax(Y_pred, axis=1)
cm = confusion_matrix(test_batches.classes, y_pred)
df_cm = pd.DataFrame(cm, list(test_batches.class_indices.keys()), list(test_batches.class_indices.keys()))
fig, ax = plt.subplots(figsize=(10,8))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}, cmap=plt.cm.Reds)
plt.title('Confusion Matrix\n')
plt.savefig('confusion_matrix.png', transparent= False, bbox_inches= 'tight', dpi= 400)
plt.show()

print('Classification Report\n')
target_names = list(test_batches.class_indices.keys())
print(classification_report(test_batches.classes, y_pred, target_names=target_names))
# Out:
# 193/193 [==============================] - 23s 119ms/step
# Classification Report
#
#                          precision    recall  f1-score   support
#
#    Basal cell carcinoma       0.62      0.45      0.52       250
#          Dermatofibroma       0.67      0.18      0.29        11
#       Actinic keratosis       0.38      0.17      0.24        75
#                Melanoma       0.59      0.33      0.42       360
#        Benign keratosis       0.35      0.34      0.35       203
#       Melanocytic nevus       0.70      0.91      0.79       965
# Squamous cell carcinoma       0.31      0.19      0.24        42
#         Vascular lesion       0.63      0.50      0.56        24
#
#                accuracy                           0.63      1930
#               macro avg       0.53      0.39      0.43      1930
#            weighted avg       0.61      0.63      0.60      1930

# %%
model.save('skin1.h5')

# %%
from keras import backend as K
from keras.layers import GlobalAveragePooling2D, GlobalMaxPooling2D, Reshape, Dense, multiply, Permute, Concatenate, Conv2D, Add, Activation, Lambda

def cbam_block(cbam_feature, ratio=8):
    """Contains the implementation of Convolutional Block Attention Module(CBAM) block.
    As described in https://arxiv.org/abs/1807.06521.
    """

    cbam_feature = channel_attention(cbam_feature, ratio)
    cbam_feature = spatial_attention(cbam_feature)
    return cbam_feature

def channel_attention(input_feature, ratio=8):

    channel_axis = 1 if K.image_data_format() == "channels_first" else -1
    channel = input_feature.shape[channel_axis]

    shared_layer_one = Dense(channel//ratio,
                             activation='relu',
                             kernel_initializer='he_normal',
                             use_bias=True,
                             bias_initializer='zeros')
    shared_layer_two = Dense(channel,
                             kernel_initializer='he_normal',
                             use_bias=True,
                             bias_initializer='zeros')

    avg_pool = GlobalAveragePooling2D()(input_feature)
    avg_pool = Reshape((1,1,channel))(avg_pool)
    assert avg_pool.shape[1:] == (1,1,channel)
    avg_pool = shared_layer_one(avg_pool)
    assert avg_pool.shape[1:] == (1,1,channel//ratio)
    avg_pool = shared_layer_two(avg_pool)
    assert avg_pool.shape[1:] == (1,1,channel)

    max_pool = GlobalMaxPooling2D()(input_feature)
    max_pool = Reshape((1,1,channel))(max_pool)
    assert max_pool.shape[1:] == (1,1,channel)
    max_pool = shared_layer_one(max_pool)
    assert max_pool.shape[1:] == (1,1,channel//ratio)
    max_pool = shared_layer_two(max_pool)
    assert max_pool.shape[1:] == (1,1,channel)

    cbam_feature = Add()([avg_pool,max_pool])
    cbam_feature = Activation('sigmoid')(cbam_feature)

    if K.image_data_format() == "channels_first":
        cbam_feature = Permute((3, 1, 2))(cbam_feature)

    return multiply([input_feature, cbam_feature])

def spatial_attention(input_feature):
    kernel_size = 7

    if K.image_data_format() == "channels_first":
        channel = input_feature.shape[1]
        cbam_feature = Permute((2,3,1))(input_feature)
    else:
        channel = input_feature.shape[-1]
        cbam_feature = input_feature

    avg_pool = Lambda(lambda x: K.mean(x, axis=3, keepdims=True))(cbam_feature)
    assert avg_pool.shape[-1] == 1
    max_pool = Lambda(lambda x: K.max(x, axis=3, keepdims=True))(cbam_feature)
    assert max_pool.shape[-1] == 1
    concat = Concatenate(axis=3)([avg_pool, max_pool])
    assert concat.shape[-1] == 2
    cbam_feature = Conv2D(filters = 1,
                    kernel_size=kernel_size,
                    strides=1,
                    padding='same',
                    activation='sigmoid',
                    kernel_initializer='he_normal',
                    use_bias=False)(concat)
    assert cbam_feature.shape[-1] == 1

    if K.image_data_format() == "channels_first":
        cbam_feature = Permute((3, 1, 2))(cbam_feature)

    return multiply([input_feature, cbam_feature])

# %%
IMG_SIZE = 224
n_classes = 8

inp = layers.Input(shape=(IMG_SIZE,IMG_SIZE,3))
x1 = layers.Resizing(IMG_SIZE, IMG_SIZE)(inp)
x2 = layers.Rescaling(1./255)(x1)
x3 = layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu',
                   padding = 'same', input_shape=(IMG_SIZE,IMG_SIZE,3))(x2)
x4 = cbam_block(x3)
x5 = layers.BatchNormalization(axis=-1)(x4)
x6 = layers.MaxPool2D(pool_size=(2, 2))(x5)
x7 = layers.Conv2D(filters=64, kernel_size=(3, 3),
                   activation='relu', padding = 'same')(x6)
x8 = cbam_block(x7)
x9 = layers.BatchNormalization(axis=-1)(x8)
x10 = layers.MaxPool2D(pool_size=(2, 2))(x9)
x11 = layers.Conv2D(filters=128, kernel_size=(3, 3),
                    activation='relu', padding = 'same')(x10)
x12 = cbam_block(x11)
x13 = layers.BatchNormalization(axis=-1)(x12)
x14 = layers.MaxPool2D(pool_size=(2, 2))(x13)
x15 = layers.Conv2D(filters=256, kernel_size=(3, 3),
                      activation='relu', padding = 'same')(x14)
x16 = cbam_block(x15)
x17 = layers.BatchNormalization(axis=-1)(x16)
x18 = layers.MaxPool2D(pool_size=(2, 2))(x17)
y1 = layers.Flatten()(x18)
y2 = layers.Dense(300, activation='relu')(y1)
y3 = layers.Dense(150, activation='relu')(y2)
y4 = layers.Dropout(0.25)(y3)
y = layers.Dense(n_classes, activation='softmax')(y4)


model_CBAM = tf.keras.Model(inp, y)
model_CBAM.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                   loss='categorical_crossentropy',
                   metrics='accuracy')
model_CBAM.summary()
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_11 (InputLayer)       [(None, 224, 224, 3)]        0         []
#
#  resizing_10 (Resizing)      (None, 224, 224, 3)          0         ['input_11[0][0]']
#
#  rescaling_10 (Rescaling)    (None, 224, 224, 3)          0         ['resizing_10[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 224, 224, 32)         896       ['rescaling_10[0][0]']
#
#  global_average_pooling2d_4  (None, 32)                   0         ['conv2d_43[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_max_pooling2d_4 (Gl  (None, 32)                   0         ['conv2d_43[0][0]']
#  obalMaxPooling2D)
#
#  reshape_8 (Reshape)         (None, 1, 1, 32)             0         ['global_average_pooling2d_4[0
#                                                                     ][0]']
#
#  reshape_9 (Reshape)         (None, 1, 1, 32)             0         ['global_max_pooling2d_4[0][0]
#                                                                     ']
#
#  dense_31 (Dense)            (None, 1, 1, 4)              132       ['reshape_8[0][0]',
#                                                                      'reshape_9[0][0]']
#
#  dense_32 (Dense)            (None, 1, 1, 32)             160       ['dense_31[0][0]',
#                                                                      'dense_31[1][0]']
#
#  add_10 (Add)                (None, 1, 1, 32)             0         ['dense_32[0][0]',
#                                                                      'dense_32[1][0]']
#
#  activation_10 (Activation)  (None, 1, 1, 32)             0         ['add_10[0][0]']
#
#  multiply_8 (Multiply)       (None, 224, 224, 32)         0         ['conv2d_43[0][0]',
#                                                                      'activation_10[0][0]']
#
#  lambda_8 (Lambda)           (None, 224, 224, 1)          0         ['multiply_8[0][0]']
#
#  lambda_9 (Lambda)           (None, 224, 224, 1)          0         ['multiply_8[0][0]']
#
#  concatenate_4 (Concatenate  (None, 224, 224, 2)          0         ['lambda_8[0][0]',
#  )                                                                   'lambda_9[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 224, 224, 1)          98        ['concatenate_4[0][0]']
#
#  multiply_9 (Multiply)       (None, 224, 224, 32)         0         ['multiply_8[0][0]',
#                                                                      'conv2d_44[0][0]']
#
#  batch_normalization_16 (Ba  (None, 224, 224, 32)         128       ['multiply_9[0][0]']
#  tchNormalization)
#
#  max_pooling2d_22 (MaxPooli  (None, 112, 112, 32)         0         ['batch_normalization_16[0][0]
#  ng2D)                                                              ']
#
#  conv2d_45 (Conv2D)          (None, 112, 112, 64)         18496     ['max_pooling2d_22[0][0]']
#
#  global_average_pooling2d_5  (None, 64)                   0         ['conv2d_45[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_max_pooling2d_5 (Gl  (None, 64)                   0         ['conv2d_45[0][0]']
#  obalMaxPooling2D)
#
#  reshape_10 (Reshape)        (None, 1, 1, 64)             0         ['global_average_pooling2d_5[0
#                                                                     ][0]']
#
#  reshape_11 (Reshape)        (None, 1, 1, 64)             0         ['global_max_pooling2d_5[0][0]
#                                                                     ']
#
#  dense_33 (Dense)            (None, 1, 1, 8)              520       ['reshape_10[0][0]',
#                                                                      'reshape_11[0][0]']
#
#  dense_34 (Dense)            (None, 1, 1, 64)             576       ['dense_33[0][0]',
#                                                                      'dense_33[1][0]']
#
#  add_11 (Add)                (None, 1, 1, 64)             0         ['dense_34[0][0]',
#                                                                      'dense_34[1][0]']
#
#  activation_11 (Activation)  (None, 1, 1, 64)             0         ['add_11[0][0]']
#
#  multiply_10 (Multiply)      (None, 112, 112, 64)         0         ['conv2d_45[0][0]',
#                                                                      'activation_11[0][0]']
#
#  lambda_10 (Lambda)          (None, 112, 112, 1)          0         ['multiply_10[0][0]']
#
#  lambda_11 (Lambda)          (None, 112, 112, 1)          0         ['multiply_10[0][0]']
#
#  concatenate_5 (Concatenate  (None, 112, 112, 2)          0         ['lambda_10[0][0]',
#  )                                                                   'lambda_11[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 112, 112, 1)          98        ['concatenate_5[0][0]']
#
#  multiply_11 (Multiply)      (None, 112, 112, 64)         0         ['multiply_10[0][0]',
#                                                                      'conv2d_46[0][0]']
#
#  batch_normalization_17 (Ba  (None, 112, 112, 64)         256       ['multiply_11[0][0]']
#  tchNormalization)
#
#  max_pooling2d_23 (MaxPooli  (None, 56, 56, 64)           0         ['batch_normalization_17[0][0]
#  ng2D)                                                              ']
#
#  conv2d_47 (Conv2D)          (None, 56, 56, 128)          73856     ['max_pooling2d_23[0][0]']
#
#  global_average_pooling2d_6  (None, 128)                  0         ['conv2d_47[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_max_pooling2d_6 (Gl  (None, 128)                  0         ['conv2d_47[0][0]']
#  obalMaxPooling2D)
#
#  reshape_12 (Reshape)        (None, 1, 1, 128)            0         ['global_average_pooling2d_6[0
#                                                                     ][0]']
#
#  reshape_13 (Reshape)        (None, 1, 1, 128)            0         ['global_max_pooling2d_6[0][0]
#                                                                     ']
#
#  dense_35 (Dense)            (None, 1, 1, 16)             2064      ['reshape_12[0][0]',
#                                                                      'reshape_13[0][0]']
#
#  dense_36 (Dense)            (None, 1, 1, 128)            2176      ['dense_35[0][0]',
#                                                                      'dense_35[1][0]']
#
#  add_12 (Add)                (None, 1, 1, 128)            0         ['dense_36[0][0]',
#                                                                      'dense_36[1][0]']
#
#  activation_12 (Activation)  (None, 1, 1, 128)            0         ['add_12[0][0]']
#
#  multiply_12 (Multiply)      (None, 56, 56, 128)          0         ['conv2d_47[0][0]',
#                                                                      'activation_12[0][0]']
#
#  lambda_12 (Lambda)          (None, 56, 56, 1)            0         ['multiply_12[0][0]']
#
#  lambda_13 (Lambda)          (None, 56, 56, 1)            0         ['multiply_12[0][0]']
#
#  concatenate_6 (Concatenate  (None, 56, 56, 2)            0         ['lambda_12[0][0]',
#  )                                                                   'lambda_13[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 56, 56, 1)            98        ['concatenate_6[0][0]']
#
#  multiply_13 (Multiply)      (None, 56, 56, 128)          0         ['multiply_12[0][0]',
#                                                                      'conv2d_48[0][0]']
#
#  batch_normalization_18 (Ba  (None, 56, 56, 128)          512       ['multiply_13[0][0]']
#  tchNormalization)
#
#  max_pooling2d_24 (MaxPooli  (None, 28, 28, 128)          0         ['batch_normalization_18[0][0]
#  ng2D)                                                              ']
#
#  conv2d_49 (Conv2D)          (None, 28, 28, 256)          295168    ['max_pooling2d_24[0][0]']
#
#  global_average_pooling2d_7  (None, 256)                  0         ['conv2d_49[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_max_pooling2d_7 (Gl  (None, 256)                  0         ['conv2d_49[0][0]']
#  obalMaxPooling2D)
#
#  reshape_14 (Reshape)        (None, 1, 1, 256)            0         ['global_average_pooling2d_7[0
#                                                                     ][0]']
#
#  reshape_15 (Reshape)        (None, 1, 1, 256)            0         ['global_max_pooling2d_7[0][0]
#                                                                     ']
#
#  dense_37 (Dense)            (None, 1, 1, 32)             8224      ['reshape_14[0][0]',
#                                                                      'reshape_15[0][0]']
#
#  dense_38 (Dense)            (None, 1, 1, 256)            8448      ['dense_37[0][0]',
#                                                                      'dense_37[1][0]']
#
#  add_13 (Add)                (None, 1, 1, 256)            0         ['dense_38[0][0]',
#                                                                      'dense_38[1][0]']
#
#  activation_13 (Activation)  (None, 1, 1, 256)            0         ['add_13[0][0]']
#
#  multiply_14 (Multiply)      (None, 28, 28, 256)          0         ['conv2d_49[0][0]',
#                                                                      'activation_13[0][0]']
#
#  lambda_14 (Lambda)          (None, 28, 28, 1)            0         ['multiply_14[0][0]']
#
#  lambda_15 (Lambda)          (None, 28, 28, 1)            0         ['multiply_14[0][0]']
#
#  concatenate_7 (Concatenate  (None, 28, 28, 2)            0         ['lambda_14[0][0]',
#  )                                                                   'lambda_15[0][0]']
#
#  conv2d_50 (Conv2D)          (None, 28, 28, 1)            98        ['concatenate_7[0][0]']
#
#  multiply_15 (Multiply)      (None, 28, 28, 256)          0         ['multiply_14[0][0]',
#                                                                      'conv2d_50[0][0]']
#
#  batch_normalization_19 (Ba  (None, 28, 28, 256)          1024      ['multiply_15[0][0]']
#  tchNormalization)
#
#  max_pooling2d_25 (MaxPooli  (None, 14, 14, 256)          0         ['batch_normalization_19[0][0]
#  ng2D)                                                              ']
#
#  flatten_7 (Flatten)         (None, 50176)                0         ['max_pooling2d_25[0][0]']
#
#  dense_39 (Dense)            (None, 300)                  1505310   ['flatten_7[0][0]']
#                                                           0
#
#  dense_40 (Dense)            (None, 150)                  45150     ['dense_39[0][0]']
#
#  dropout_7 (Dropout)         (None, 150)                  0         ['dense_40[0][0]']
#
#  dense_41 (Dense)            (None, 8)                    1208      ['dropout_7[0][0]']
#
# ==================================================================================================
# Total params: 15512486 (59.18 MB)
# Trainable params: 15511526 (59.17 MB)
# Non-trainable params: 960 (3.75 KB)
# __________________________________________________________________________________________________

# %%
history_CBAM = model_CBAM.fit(x=train_batches,
                              validation_data=validation_batches,
                              steps_per_epoch=len(train_batches),
                              validation_steps=len(validation_batches),
                              epochs=10,
                              batch_size=BATCH_SIZE,
                              verbose=1)
# Out:
# Epoch 1/10
# 1935/1935 [==============================] - 358s 164ms/step - loss: 1.2058 - accuracy: 0.5741 - val_loss: 1.4075 - val_accuracy: 0.4706
# Epoch 2/10
# 1935/1935 [==============================] - 339s 175ms/step - loss: 1.0463 - accuracy: 0.6307 - val_loss: 1.3647 - val_accuracy: 0.4860
# Epoch 3/10
# 1935/1935 [==============================] - 310s 160ms/step - loss: 0.9606 - accuracy: 0.6554 - val_loss: 1.4359 - val_accuracy: 0.5177
# Epoch 4/10
# 1935/1935 [==============================] - 309s 160ms/step - loss: 0.8844 - accuracy: 0.6876 - val_loss: 1.4562 - val_accuracy: 0.5242
# Epoch 5/10
#  620/1935 [========>.....................] - ETA: 3:07 - loss: 0.7918 - accuracy: 0.7187

# %%
img_path = '/kaggle/input/isic-2019/ISIC - 2019/test/Basal cell carcinoma/ISIC_0024461.jpg'

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import seaborn as sn
num_classes = len(train_batches.class_indices)
train_labels = train_batches.classes
train_labels = to_categorical(train_labels, num_classes=num_classes)
valid_labels = validation_batches.classes
valid_labels = to_categorical(valid_labels, num_classes=num_classes)
nb_train_samples = len(train_batches.filenames)
nb_valid_samples = len(validation_batches.filenames)
nb_test_samples = len(test_batches.filenames)
Y_pred = model_CBAM.predict(test_batches, nb_test_samples // BATCH_SIZE+1)
y_pred = np.argmax(Y_pred, axis=1)
cm = confusion_matrix(test_batches.classes, y_pred)
df_cm = pd.DataFrame(cm, list(test_batches.class_indices.keys()), list(test_batches.class_indices.keys()))
fig, ax = plt.subplots(figsize=(10,8))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}, cmap=plt.cm.Reds)
plt.title('Confusion Matrix\n')
plt.savefig('confusion_matrix.png', transparent= False, bbox_inches= 'tight', dpi= 400)
plt.show()

print('Classification Report\n')
target_names = list(test_batches.class_indices.keys())
print(classification_report(test_batches.classes, y_pred, target_names=target_names))
